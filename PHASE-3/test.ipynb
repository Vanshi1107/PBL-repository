# %%
from predict import predict_patient

# Example patient data (USE EXACT FEATURE NAMES from your dataset)
sample_patient = {
    "Age": 58,
    "RestingBP": 150,
    "MaxHR": 135,
    "Oldpeak": 1.2,

    "Sex_M": 1,

    "ChestPainType_ATA": 0,
    "ChestPainType_NAP": 1,

    "ExerciseAngina_Y": 0,

    "ST_Slope_Flat": 0,
    "ST_Slope_Up": 1
}

prediction, probability = predict_patient(sample_patient)

print("Prediction:", "Disease" if prediction == 1 else "No Disease")
print("Probability of Disease:", round(probability, 4))
# Out:
# Prediction: No Disease
# Probability of Disease: 0.2922

# %%
import pickle

features = pickle.load(open("selected_features.pkl", "rb"))
print(features)
# Out:
# Index(['Age', 'RestingBP', 'MaxHR', 'Oldpeak', 'Sex_M', 'ChestPainType_ATA',
#        'ChestPainType_NAP', 'ExerciseAngina_Y', 'ST_Slope_Flat',
#        'ST_Slope_Up'],
#       dtype='str')
